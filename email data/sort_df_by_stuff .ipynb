# %% [markdown]
# # Subject1: process mock dataset
#
#
# Three cases:
#
# - sender1 will send an email at 22h then 7h
# - sender2 will send an email at 22h then 7h one day apart
# - sender3 will send an email at 21h then 8h the next day

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
email_df = pd.read_csv("/content/drive/MyDrive/AI/problems/mock.csv")

# %%
email_df
# Out:
#     email_id             sender             receiver             datetime  \
# 0       1123  sender1@gmail.com  receiver1@gmail.com  01/01/2020 10:55:02
# 1       1456  sender1@gmail.com  receiver2@gmail.com  01/01/2020 11:55:02
# 2       1789  sender1@gmail.com  receiver3@gmail.com  01/01/2020 12:55:02
# 3       1101  sender1@gmail.com  receiver4@gmail.com  01/01/2020 22:55:02
# 4       1112  sender1@gmail.com  receiver5@gmail.com  02/01/2020 07:55:02
# 5       2123  sender2@gmail.com  receiver1@gmail.com  01/01/2020 10:55:02
# 6       2456  sender2@gmail.com  receiver2@gmail.com  01/01/2020 11:55:02
# 7       2789  sender2@gmail.com  receiver3@gmail.com  01/01/2020 12:55:02
# 8       2101  sender2@gmail.com  receiver4@gmail.com  01/01/2020 21:55:02
# 9       2112  sender2@gmail.com  receiver5@gmail.com  02/01/2020 06:55:02
# 10      3123  sender2@gmail.com  receiver1@gmail.com  01/01/2020 10:55:02
# 11      3456  sender2@gmail.com  receiver2@gmail.com  01/01/2020 11:55:02
# 12      3789  sender2@gmail.com  receiver3@gmail.com  01/01/2020 12:55:02
# 13      3101  sender2@gmail.com  receiver4@gmail.com  01/01/2020 21:00:00
# 14      3112  sender2@gmail.com  receiver5@gmail.com  03/01/2020 07:00:00
# 15      4112  sender2@gmail.com  receiver5@gmail.com  04/01/2020 08:00:00
# 16      4112  sender2@gmail.com  receiver5@gmail.com  04/01/2020 11:00:00
# 17      4112  sender2@gmail.com  receiver5@gmail.com  05/01/2020 07:00:00
# 18      4112  sender2@gmail.com  receiver5@gmail.com  05/01/2020 10:00:00
#
#               object
# 0     normal email 1
# 1     normal email 2
# 2     normal email 3
# 3     normal email 4
# 4   abnormal email 1
# 5     normal email 1
# 6     normal email 2
# 7     normal email 3
# 8     normal email 4
# 9   abnormal email 1
# 10    normal email 1
# 11    normal email 2
# 12    normal email 3
# 13    normal email 4
# 14    normal email 5
# 15   weekend email 1
# 16   weekend email 2
# 17   weekend email 3
# 18   weekend email 4

# %% [markdown]
# ## add 11h appart flag

# %%
# Convert 'datetime' to datetime
email_df['datetime'] = pd.to_datetime(email_df['datetime'], format='%d/%m/%Y %H:%M:%S')

# Create a separate column for the date only (no time)
email_df['date'] = email_df['datetime'].dt.date

# Sort DataFrame by sender and datetime
email_df = email_df.sort_values(['sender', 'datetime'])

# Calculate difference between consecutive emails for each sender
email_df['time_diff'] = email_df.groupby('sender')['datetime'].diff()
email_df['date_diff'] = email_df.groupby('sender')['date'].diff()

# Flag the emails sent less than 11 hours apart on consecutive days
email_df['less_than_11h'] = (email_df['time_diff'].dt.total_seconds() / 3600 < 11) & (email_df['date_diff'].dt.days == 1)

# %% [markdown]
# We delete useless features used during the flagging step

# %%
del email_df['date_diff']
del email_df['time_diff']

# 5       2123  sender2@gmail.com  receiver1@gmail.com 2020-01-01 10:55:02
# 10      3123  sender2@gmail.com  receiver1@gmail.com 2020-01-01 10:55:02
# 6       2456  sender2@gmail.com  receiver2@gmail.com 2020-01-01 11:55:02
# 11      3456  sender2@gmail.com  receiver2@gmail.com 2020-01-01 11:55:02
# 7       2789  sender2@gmail.com  receiver3@gmail.com 2020-01-01 12:55:02
# 12      3789  sender2@gmail.com  receiver3@gmail.com 2020-01-01 12:55:02
# 13      3101  sender2@gmail.com  receiver4@gmail.com 2020-01-01 21:00:00
# 8       2101  sender2@gmail.com  receiver4@gmail.com 2020-01-01 21:55:02
# 9       2112  sender2@gmail.com  receiver5@gmail.com 2020-01-02 06:55:02
# 14      3112  sender2@gmail.com  receiver5@gmail.com 2020-01-03 07:00:00
# 15      4112  sender2@gmail.com  receiver5@gmail.com 2020-01-04 08:00:00
# 16      4112  sender2@gmail.com  receiver5@gmail.com 2020-01-04 11:00:00
# 17      4112  sender2@gmail.com  receiver5@gmail.com 2020-01-05 07:00:00
# 18      4112  sender2@gmail.com  receiver5@gmail.com 2020-01-05 10:00:00
#
#               object        date  less_than_11h  is_sent_before_8h  \
# 0     normal email 1  2020-01-01          False               True
# 1     normal email 2  2020-01-01          False               True
# 2     normal email 3  2020-01-01          False               True
# 3     normal email 4  2020-01-01          False               True
# 4   abnormal email 1  2020-01-02           True              False
# 5     normal email 1  2020-01-01          False               True
# 10    normal email 1  2020-01-01          False               True
# 6     normal email 2  2020-01-01          False               True
# 11    normal email 2  2020-01-01          False               True
# 7     normal email 3  2020-01-01          False               True
# 12    normal email 3  2020-01-01          False               True
# 13    normal email 4  2020-01-01          False               True
# 8     normal email 4  2020-01-01          False               True
# 9   abnormal email 1  2020-01-02           True              False
# 14    normal email 5  2020-01-03          False              False
# 15   weekend email 1  2020-01-04          False               True
# 16   weekend email 2  2020-01-04          False               True
# 17   weekend email 3  2020-01-05          False              False
# 18   weekend email 4  2020-01-05          False               True
#
#     is_sent_after_21h
# 0               False
# 1               False
# 2               False
# 3                True
# 4               False
# 5               False
# 10              False
# 6               False
# 11              False
# 7               False
# 12              False
# 13               True
# 8                True
# 9               False
# 14              False
# 15              False
# 16              False
# 17              False
# 18              False

# %% [markdown]
# ### Sent on saturday and sent on sunday

# %%
email_df['day_name'] = email_df.datetime.dt.day_name()

email_df['is_sent_on_sunday'] = email_df.day_name.isin(['Sunday'])
email_df['is_sent_on_saturday'] = email_df.day_name.isin(['Saturday'])

# %% [markdown]
# ### extract name of sender and receiver

# %% [markdown]
# #### replace emails with realistic emails in the mock dataset

# %%
email_df['sender'] = email_df['sender'].str.replace('sender1@gmail.com', 'Bryan Temp <bryan.temp@gmail.com>')
email_df['sender'] = email_df['sender'].str.replace('sender2@gmail.com', 'Kelly Kapoor <kelly.kapoor@gmail.com>')
email_df.head()
# Out:
# <ipython-input-69-5fe0025f2bb5>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['sender'] = email_df['sender'].str.replace('sender1@gmail.com', 'Bryan Temp <bryan.temp@gmail.com>')
# <ipython-input-69-5fe0025f2bb5>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['sender'] = email_df['sender'].str.replace('sender2@gmail.com', 'Kelly Kapoor <kelly.kapoor@gmail.com>')
#    email_id                             sender             receiver  \
# 0      1123  Bryan Temp <bryan.temp@gmail.com>  receiver1@gmail.com
# 1      1456  Bryan Temp <bryan.temp@gmail.com>  receiver2@gmail.com
# 2      1789  Bryan Temp <bryan.temp@gmail.com>  receiver3@gmail.com
# 3      1101  Bryan Temp <bryan.temp@gmail.com>  receiver4@gmail.com
# 4      1112  Bryan Temp <bryan.temp@gmail.com>  receiver5@gmail.com
#
#              datetime            object        date  less_than_11h  \
# 0 2020-01-01 10:55:02    normal email 1  2020-01-01          False
# 1 2020-01-01 11:55:02    normal email 2  2020-01-01          False
# 2 2020-01-01 12:55:02    normal email 3  2020-01-01          False
# 3 2020-01-01 22:55:02    normal email 4  2020-01-01          False
# 4 2020-01-02 07:55:02  abnormal email 1  2020-01-02           True
#
#    is_sent_before_8h  is_sent_after_21h   day_name  is_sent_on_sunday  \
# 0               True              False  Wednesday              False
# 1               True              False  Wednesday              False
# 2               True              False  Wednesday              False
# 3               True               True  Wednesday              False
# 4              False              False   Thursday              False
#
#    is_sent_on_saturday
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
email_df['receiver'] = email_df['receiver'].str.replace('receiver1@gmail.com', 'Michael Scott <michael.scott@gmail.com>, Dwight Shrutte <dwight.schrutte@gmail.com>')
email_df['receiver'] = email_df['receiver'].str.replace('receiver2@gmail.com', 'Jim Halpert <jim.halpert@gmail.com>, Maredith Palmer <meredith.palmer@gmail.com>')
email_df['receiver'] = email_df['receiver'].str.replace('receiver3@gmail.com', 'Michael Scott <michael.scott@gmail.com>, Dwight Shrutte <dwight.schrutte@gmail.com>, Jim Halpert <jim.halpert@gmail.com>, Maredith Palmer <meredith.palmer@gmail.com>')
email_df['receiver'] = email_df['receiver'].str.replace('receiver4@gmail.com', 'Michael Scott <michael.scott@gmail.com>')
email_df['receiver'] = email_df['receiver'].str.replace('receiver5@gmail.com', 'Michael Scott <michael.scott@gmail.com>, Dwight Shrutte <dwight.schrutte@gmail.com>, Toby Flenderson <toby.flenderson@gmail.com>')
email_df
# Out:
# <ipython-input-70-26515af209c0>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['receiver'] = email_df['receiver'].str.replace('receiver1@gmail.com', 'Michael Scott <michael.scott@gmail.com>, Dwight Shrutte <dwight.schrutte@gmail.com>')
# <ipython-input-70-26515af209c0>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['receiver'] = email_df['receiver'].str.replace('receiver2@gmail.com', 'Jim Halpert <jim.halpert@gmail.com>, Maredith Palmer <meredith.palmer@gmail.com>')
# <ipython-input-70-26515af209c0>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['receiver'] = email_df['receiver'].str.replace('receiver3@gmail.com', 'Michael Scott <michael.scott@gmail.com>, Dwight Shrutte <dwight.schrutte@gmail.com>, Jim Halpert <jim.halpert@gmail.com>, Maredith Palmer <meredith.palmer@gmail.com>')
# <ipython-input-70-26515af209c0>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   email_df['receiver'] = email_df['receiver'].str.replace('receiver4@gmail.com', 'Michael Scott <michael.scott@gmail.com>')
# <ipython-input-70-26515af209c0>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#
# 18  Michael Scott <michael.scott@gmail.com>, Dwigh... 2020-01-05 10:00:00
#
#               object        date  less_than_11h  is_sent_before_8h  \
# 0     normal email 1  2020-01-01          False               True
# 1     normal email 2  2020-01-01          False               True
# 2     normal email 3  2020-01-01          False               True
# 3     normal email 4  2020-01-01          False               True
# 4   abnormal email 1  2020-01-02           True              False
# 5     normal email 1  2020-01-01          False               True
# 10    normal email 1  2020-01-01          False               True
# 6     normal email 2  2020-01-01          False               True
# 11    normal email 2  2020-01-01          False               True
# 7     normal email 3  2020-01-01          False               True
# 12    normal email 3  2020-01-01          False               True
# 13    normal email 4  2020-01-01          False               True
# 8     normal email 4  2020-01-01          False               True
# 9   abnormal email 1  2020-01-02           True              False
# 14    normal email 5  2020-01-03          False              False
# 15   weekend email 1  2020-01-04          False               True
# 16   weekend email 2  2020-01-04          False               True
# 17   weekend email 3  2020-01-05          False              False
# 18   weekend email 4  2020-01-05          False               True
#
#     is_sent_after_21h   day_name  is_sent_on_sunday  is_sent_on_saturday
# 0               False  Wednesday              False                False
# 1               False  Wednesday              False                False
# 2               False  Wednesday              False                False
# 3                True  Wednesday              False                False
# 4               False   Thursday              False                False
# 5               False  Wednesday              False                False
# 10              False  Wednesday              False                False
# 6               False  Wednesday              False                False
# 11              False  Wednesday              False                False
# 7               False  Wednesday              False                False
# 12              False  Wednesday              False                False
# 13               True  Wednesday              False                False
# 8                True  Wednesday              False                False
# 9               False   Thursday              False                False
# 14              False     Friday              False                False
# 15              False   Saturday              False                 True
# 16              False   Saturday              False                 True
# 17              False     Sunday               True                False
# 18              False     Sunday               True                False

# %% [markdown]
# #### extract name and surname function

# %%
import re

def extract_names_from_emails(input_string):
    # Step 1: Detect all email addresses using regular expression
    email_regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}\b'
    emails = re.findall(email_regex, input_string)

    name_surname_couples = []
    for email in emails:
        # Step 2: Extract name and surname from email address
        name, surname = email.split('@')[0].split('.')

        # Step 3: Capitalize first letter of name and surname
        name = name.lower().capitalize()
        surname = surname.lower().capitalize()

        # Step 4: Append name and surname to the couples list
        name_surname_couples.append(f"{name} {surname}")

    # Return all name and surname couples separated by ";"
    return ";".join(name_surname_couples)

# %%
text = "Hello, my email address is john.doe@example.com. Please contact me if you have any questions. louis.paulet@gmail.com"
email_addresses = extract_names_from_emails(text)
print("Email Addresses:", email_addresses)
# Out:
# Email Addresses: John Doe;Louis Paulet

# %% [markdown]
# #### apply extraction of name and surname

# %%
email_df['sender_name'] = email_df.sender.apply(extract_names_from_emails)
email_df['receiver_name'] = email_df.receiver.apply(extract_names_from_emails)
email_df
# Out:
#     email_id                                 sender  \
# 0       1123      Bryan Temp <bryan.temp@gmail.com>
# 1       1456      Bryan Temp <bryan.temp@gmail.com>
# 2       1789      Bryan Temp <bryan.temp@gmail.com>
# 3       1101      Bryan Temp <bryan.temp@gmail.com>
# 4       1112      Bryan Temp <bryan.temp@gmail.com>
# 5       2123  Kelly Kapoor <kelly.kapoor@gmail.com>
# 10      3123  Kelly Kapoor <kelly.kapoor@gmail.com>
# 9   abnormal email 1  2020-01-02           True              False
# 14    normal email 5  2020-01-03          False              False
# 15   weekend email 1  2020-01-04          False               True
# 16   weekend email 2  2020-01-04          False               True
# 17   weekend email 3  2020-01-05          False              False
# 18   weekend email 4  2020-01-05          False               True
#
#     is_sent_after_21h   day_name  is_sent_on_sunday  is_sent_on_saturday  \
# 0               False  Wednesday              False                False
# 1               False  Wednesday              False                False
# 2               False  Wednesday              False                False
# 3                True  Wednesday              False                False
# 4               False   Thursday              False                False
# 5               False  Wednesday              False                False
# 10              False  Wednesday              False                False
# 6               False  Wednesday              False                False
# 11              False  Wednesday              False                False
# 7               False  Wednesday              False                False
# 12              False  Wednesday              False                False
# 13               True  Wednesday              False                False
# 8                True  Wednesday              False                False
# 9               False   Thursday              False                False
# 14              False     Friday              False                False
# 15              False   Saturday              False                 True
# 16              False   Saturday              False                 True
# 17              False     Sunday               True                False
# 18              False     Sunday               True                False
#
#      sender_name                                      receiver_name
# 0     Bryan Temp                      Michael Scott;Dwight Schrutte
# 1     Bryan Temp                        Jim Halpert;Meredith Palmer
# 2     Bryan Temp  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 3     Bryan Temp                                      Michael Scott
# 4     Bryan Temp      Michael Scott;Dwight Schrutte;Toby Flenderson
# 5   Kelly Kapoor                      Michael Scott;Dwight Schrutte
# 10  Kelly Kapoor                      Michael Scott;Dwight Schrutte
# 6   Kelly Kapoor                        Jim Halpert;Meredith Palmer
# 11  Kelly Kapoor                        Jim Halpert;Meredith Palmer
# 7   Kelly Kapoor  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 12  Kelly Kapoor  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 13  Kelly Kapoor                                      Michael Scott
# 8   Kelly Kapoor                                      Michael Scott
# 9   Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 14  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 15  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 16  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 17  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 18  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson

# %% [markdown]
# # Subject2: Parse weird date
#
# TLDR: doesn't change anything, only a problem in certain times of the year

# %%
import pytz
from dateutil import parser

def convert_to_datetime(time_string):
    # Check if string contains 'CEST' or 'CET'
    if "CEST" in time_string:
        # Convert the string into datetime object without timezone
        date_without_tz = parser.parse(time_string.replace("CEST", "").strip())
        # Define CEST timezone
        tz = pytz.timezone('Europe/Paris')
    elif "CET" in time_string:
        # Convert the string into datetime object without timezone
        date_without_tz = parser.parse(time_string.replace("CET", "").strip())
        # Define CET timezone
        tz = pytz.timezone('CET')

    # Add the timezone to the datetime object
    date_with_tz = tz.localize(date_without_tz)

    return date_with_tz

# %%
time_string = "06/22/22 5:17:55 PM CET"
result = convert_to_datetime(time_string)
print(result)

time_string = "06/22/22 5:17:55 PM CEST"
# 18  Michael Scott <michael.scott@gmail.com>, Dwigh... 2020-01-05 10:00:00
#
#               object        date  less_than_11h  is_sent_before_8h  \
# 0     normal email 1  2020-01-01          False               True
# 1     normal email 2  2020-01-01          False               True
# 2     normal email 3  2020-01-01          False               True
# 3     normal email 4  2020-01-01          False               True
# 4   abnormal email 1  2020-01-02           True              False
# 5     normal email 1  2020-01-01          False               True
# 10    normal email 1  2020-01-01          False               True
# 6     normal email 2  2020-01-01          False               True
# 11    normal email 2  2020-01-01          False               True
# 7     normal email 3  2020-01-01          False               True
# 12    normal email 3  2020-01-01          False               True
# 13    normal email 4  2020-01-01          False               True
# 8     normal email 4  2020-01-01          False               True
# 9   abnormal email 1  2020-01-02           True              False
# 14    normal email 5  2020-01-03          False              False
# 15   weekend email 1  2020-01-04          False               True
# 16   weekend email 2  2020-01-04          False               True
# 17   weekend email 3  2020-01-05          False              False
# 18   weekend email 4  2020-01-05          False               True
#
#     is_sent_after_21h   day_name  is_sent_on_sunday  is_sent_on_saturday  \
# 0               False  Wednesday              False                False
# 1               False  Wednesday              False                False
# 2               False  Wednesday              False                False
# 3                True  Wednesday              False                False
# 4               False   Thursday              False                False
# 5               False  Wednesday              False                False
# 10              False  Wednesday              False                False
# 6               False  Wednesday              False                False
# 11              False  Wednesday              False                False
# 7               False  Wednesday              False                False
# 12              False  Wednesday              False                False
# 13               True  Wednesday              False                False
# 8                True  Wednesday              False                False
# 9               False   Thursday              False                False
# 14              False     Friday              False                False
# 15              False   Saturday              False                 True
# 16              False   Saturday              False                 True
# 17              False     Sunday               True                False
# 18              False     Sunday               True                False
#
#      sender_name                                      receiver_name
# 0     Bryan Temp                      Michael Scott;Dwight Schrutte
# 1     Bryan Temp                        Jim Halpert;Meredith Palmer
# 2     Bryan Temp  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 3     Bryan Temp                                      Michael Scott
# 4     Bryan Temp      Michael Scott;Dwight Schrutte;Toby Flenderson
# 5   Kelly Kapoor                      Michael Scott;Dwight Schrutte
# 10  Kelly Kapoor                      Michael Scott;Dwight Schrutte
# 6   Kelly Kapoor                        Jim Halpert;Meredith Palmer
# 11  Kelly Kapoor                        Jim Halpert;Meredith Palmer
# 7   Kelly Kapoor  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 12  Kelly Kapoor  Michael Scott;Dwight Schrutte;Jim Halpert;Mere...
# 13  Kelly Kapoor                                      Michael Scott
# 8   Kelly Kapoor                                      Michael Scott
# 9   Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 14  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 15  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 16  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 17  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson
# 18  Kelly Kapoor      Michael Scott;Dwight Schrutte;Toby Flenderson

# %%
import csv
email_df.to_csv('/content/drive/MyDrive/AI/problems/mock_export.csv', sep='|', quoting=csv.QUOTE_ALL)
